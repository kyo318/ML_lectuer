# %%
import torch 
import torch.nn as nn 
import torch.nn.functional as F 
import torch.optim as optim

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x_train = torch.FloatTensor([[73, 80, 75],
                             [93, 88, 93],
                             [89, 91, 80], 
                             [96, 98, 100], 
                             [73, 66, 70]])
y_train = torch.FloatTensor([[152], [185], [180], [196], [142]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Model Initialization
W = torch.zeros((3, 1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %%
optimizer = optim.SGD([W, b], lr=1e-5)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
epochs = 20
for epoch in range(1, epochs + 1):
    hypothesis = x_train.matmul(W) + b 

    cost = torch.mean((hypothesis - y_train)**2)

    optimizer.zero_grad() 
    cost.backward()
    optimizer.step()
    print(f'Epoch {epoch}/{epochs} hypothesis: {hypothesis.squeeze().detach()}, Cost: {cost.item()}')
# Out:
# Epoch 1/20 hypothesis: tensor([0., 0., 0., 0., 0.]), Cost: 29661.80078125
# Epoch 2/20 hypothesis: tensor([66.7178, 80.1701, 76.1025, 86.0194, 61.1565]), Cost: 9537.6943359375
# Epoch 3/20 hypothesis: tensor([104.5421, 125.6208, 119.2478, 134.7861,  95.8280]), Cost: 3069.59033203125
# Epoch 4/20 hypothesis: tensor([125.9858, 151.3882, 143.7087, 162.4333, 115.4844]), Cost: 990.6707153320312
# Epoch 5/20 hypothesis: tensor([138.1429, 165.9963, 157.5768, 178.1071, 126.6283]), Cost: 322.4819030761719
# Epoch 6/20 hypothesis: tensor([145.0350, 174.2780, 165.4395, 186.9928, 132.9461]), Cost: 107.71700286865234
# Epoch 7/20 hypothesis: tensor([148.9423, 178.9731, 169.8976, 192.0301, 136.5279]), Cost: 38.687400817871094
# Epoch 8/20 hypothesis: tensor([151.1574, 181.6347, 172.4254, 194.8856, 138.5585]), Cost: 16.499032974243164
# Epoch 9/20 hypothesis: tensor([152.4131, 183.1435, 173.8590, 196.5043, 139.7097]), Cost: 9.365659713745117
# Epoch 10/20 hypothesis: tensor([153.1250, 183.9988, 174.6723, 197.4217, 140.3625]), Cost: 7.071113586425781
# Epoch 11/20 hypothesis: tensor([153.5285, 184.4835, 175.1338, 197.9415, 140.7325]), Cost: 6.331867218017578
# Epoch 12/20 hypothesis: tensor([153.7572, 184.7582, 175.3958, 198.2360, 140.9424]), Cost: 6.092538356781006
# Epoch 13/20 hypothesis: tensor([153.8868, 184.9138, 175.5449, 198.4026, 141.0614]), Cost: 6.013822555541992
# Epoch 14/20 hypothesis: tensor([153.9602, 185.0019, 175.6299, 198.4969, 141.1288]), Cost: 5.9867777824401855
# Epoch 15/20 hypothesis: tensor([154.0017, 185.0517, 175.6785, 198.5501, 141.1671]), Cost: 5.976319313049316
# Epoch 16/20 hypothesis: tensor([154.0252, 185.0798, 175.7065, 198.5800, 141.1888]), Cost: 5.971208095550537
# Epoch 17/20 hypothesis: tensor([154.0385, 185.0956, 175.7229, 198.5966, 141.2012]), Cost: 5.967835426330566
# Epoch 18/20 hypothesis: tensor([154.0459, 185.1045, 175.7326, 198.6059, 141.2082]), Cost: 5.964968681335449
# Epoch 19/20 hypothesis: tensor([154.0501, 185.1094, 175.7386, 198.6108, 141.2122]), Cost: 5.962291240692139
# Epoch 20/20 hypothesis: tensor([154.0524, 185.1120, 175.7424, 198.6134, 141.2145]), Cost: 5.959676265716553

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import torch 
import torch.nn as nn 
import torch.nn.functional as F 
import torch.optim as optim 

class MultivariateLinearRegression(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3, 1)

    def forward(self, x):
        return self.linear(x)

x_train = torch.FloatTensor([[73, 80, 75],
                             [93, 88, 93],
                             [89, 91, 80], 
                             [96, 98, 100], 
                             [73, 66, 70]])
y_train = torch.FloatTensor([[152], [185], [180], [196], [142]])

model = MultivariateLinearRegression()

# Model Initialization
#W = torch.zeros((3, 1), requires_grad=True)
#b = torch.zeros(1, requires_grad=True)
optimizer = optim.SGD(model.parameters(), lr=1e-5)
#optimizer = optim.SGD([W, b], lr=1e-5)

epochs = 20
for epoch in range(1, epochs + 1):

    prediction = model(x_train)
    #hypothesis = x_train.matmul(W) + b 

    cost = F.mse_loss(prediction, y_train)
    #cost = torch.mean((hypothesis - y_train)**2)

    optimizer.zero_grad() 
    cost.backward()
    optimizer.step()
    print(f'Epoch {epoch}/{epochs} Cost: {cost.item()}')
# Out:
# Epoch 1/20 Cost: 19593.94921875
# Epoch 2/20 Cost: 6311.22900390625
# Epoch 3/20 Cost: 2042.0162353515625
# Epoch 4/20 Cost: 669.839599609375
# Epoch 5/20 Cost: 228.80221557617188
# Epoch 6/20 Cost: 87.04257202148438
# Epoch 7/20 Cost: 41.47417449951172
# Epoch 8/20 Cost: 26.82268714904785
# Epoch 9/20 Cost: 22.10809326171875
# Epoch 10/20 Cost: 20.58743667602539
# Epoch 11/20 Cost: 20.093311309814453
# Epoch 12/20 Cost: 19.92905616760254
# Epoch 13/20 Cost: 19.870899200439453
# Epoch 14/20 Cost: 19.846851348876953
# Epoch 15/20 Cost: 19.833757400512695
# Epoch 16/20 Cost: 19.824193954467773
# Epoch 17/20 Cost: 19.81574249267578
# Epoch 18/20 Cost: 19.807695388793945
# Epoch 19/20 Cost: 19.799694061279297
# Epoch 20/20 Cost: 19.79180145263672
